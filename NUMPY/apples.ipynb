# %%
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'

# %%
dado = np.loadtxt(url, delimiter=',', usecols=np.arange(1, 88, 1))

# %%
dado.ndim
# Out:
# 2

# %%
dado.size
# Out:
# 522

# %%
dado.shape
# Out:
# (6, 87)

# %%
dado_transposto = dado.T

# %%
dado_transposto
# Out:
# array([[  1.2013,  79.72  ,  42.67  ,  62.55  ,  48.26  ,  71.25  ],
#        [  2.2013,  81.08  ,  44.37  ,  62.73  ,  51.01  ,  71.35  ],
#        [  3.2013,  79.68  ,  44.73  ,  63.43  ,  50.91  ,  70.9   ],
#        [  4.2013,  79.8   ,  46.75  ,  63.83  ,  53.94  ,  71.92  ],
#        [  5.2013,  80.63  ,      nan,  66.06  ,  61.27  ,  72.91  ],
#        [  6.2013,  80.8   ,  51.59  ,  69.22  ,  65.44  ,  74.39  ],
#        [  7.2013,  80.28  ,  57.8   ,  72.07  ,  56.51  ,  73.1   ],
#        [  8.2013,  78.99  ,  62.14  ,  69.31  ,  53.    ,  70.24  ],
#        [  9.2013,  76.77  ,  56.76  ,  65.18  ,  43.87  ,  69.12  ],
#        [ 10.2013,  76.09  ,  50.85  ,  62.13  ,  42.12  ,  68.98  ],
#        [ 11.2013,  76.36  ,  46.43  ,  64.17  ,  43.98  ,  68.58  ],
#        [ 12.2013,  77.16  ,  46.73  ,  65.5   ,  44.66  ,  69.5   ],
#        [  1.2014,  77.5   ,  45.85  ,  66.85  ,  47.73  ,  70.14  ],
#        [  2.2014,  79.03  ,  49.25  ,  68.38  ,  52.31  ,  70.58  ],
# ...

# %%
datas = dado_transposto[:, 0] #primeira coluna com datas

# %%
precos = dado_transposto[:, 1:6] # 1:6 -> 1, 2, 3, 4, 5

# %%
from IPython.display import Image
Image(url='https://pt-static.z-dn.net/files/d57/ff4547df0a82d72969f23b720592231c.gif')
# Out:
# <img src="https://pt-static.z-dn.net/files/d57/ff4547df0a82d72969f23b720592231c.gif"/>

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1, 88, 1)#transformando meses em numeros individuais para plotar ex: 1 = 1.2013, 2 = 2.2013, 3 = 3.2013

# %%
plt.plot(datas, precos[:, 0])

# %%
Moscow = precos[:, 0]
Kalliningrad = precos[:, 1]
Petersburg = precos[:, 2]
Krasnodar = precos[:, 3]
Ekatirinburg = precos[:, 4]

# %%
#separando os anos
Moscow_ano1 = Moscow[0:12] 
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
plt.plot(np.arange(1,13,1), Moscow_ano1)
plt.plot(np.arange(1,13,1), Moscow_ano2)
plt.plot(np.arange(1,13,1), Moscow_ano3)
plt.plot(np.arange(1,13,1), Moscow_ano4)
plt.legend(['ano1', 'ano2', 'ano3', 'ano4'])

# %%
np.array_equal(Moscow_ano3, Moscow_ano4)
# Out:
# False

# %%
np.allclose(Moscow_ano3, Moscow_ano4, 10)#Não tem uma diferença maior que 10 entre os valores dos arrays
# Out:
# True

# %%
plt.plot(datas, Kalliningrad) #TEMOS UM PEDAÇO FALTANDO nan

# %%
Kalliningrad #Temos um Nan
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
sum(np.isnan(Kalliningrad)) #Descobrindo quantos Nan temos
# Out:
# 1

# %%
(Kalliningrad[3] + Kalliningrad[5]) / 2 #calculando a média dos valores antes e depois do Nan
# Out:
# 49.17

# %%
Kalliningrad[4] = np.mean([Kalliningrad[3], Kalliningrad[5]]) #substituindo o Nan pela média dos valores antes e depois

# %%
plt.plot(datas, Kalliningrad) #plotando o gráfico novamente

# %% [markdown]
# CALCULANDO A MÉDIA DE VALOR DE 2 CIDADES

# %%
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
np.mean(Kalliningrad)
# Out:
# 74.5506896551724

# %%
plt.plot(Moscow)

# %% [markdown]
# y = ax+b é a equação da reta

# %%
x = datas

# %%
y = 2*x + 80

# %%
plt.plot(datas, Moscow)
plt.plot(x, y)

# %%
np.power(Moscow-y,2)
# Out:
# array([5.19840000e+00, 8.52640000e+00, 3.99424000e+01, 6.72400000e+01,
#        8.77969000e+01, 1.25440000e+02, 1.88238400e+02, 2.89340100e+02,
#        4.50712900e+02, 5.71688100e+02, 6.57409600e+02, 7.20385600e+02,
#        8.12250000e+02, 8.39260900e+02, 8.83278400e+02, 1.02080250e+03,
#        1.28809210e+03, 1.52881000e+03, 1.62570240e+03, 1.93160250e+03,
#        2.15946090e+03, 2.56137210e+03, 2.26956960e+03, 1.50854560e+03,
#        6.03684900e+02, 7.38752400e+02, 1.07912250e+03, 1.39651690e+03,
#        1.44704160e+03, 1.82414410e+03, 1.88008960e+03, 1.57926760e+03,
#        1.88095690e+03, 2.43640960e+03, 2.79100890e+03, 2.90628810e+03,
#        2.59386490e+03, 2.09214760e+03, 2.22406560e+03, 2.27719840e+03,
#        2.59081000e+03, 2.90952360e+03, 2.73529000e+03, 3.03821440e+03,
#        4.61312640e+03, 5.84613160e+03, 6.83432890e+03, 7.39772010e+03,
#        7.49263360e+03, 7.48052010e+03, 7.81456000e+03, 8.13964840e+03,
# ...

# %% [markdown]
# CALCULANDO O COEFICIENTE ANGULAR

# %% [markdown]
# Suponha que você esteja analisando a relação entre a quantidade de widgets vendidos (Q) e o preço desses widgets (P). Se a equação for Q = -2P + 100, significa que para cada aumento de $1 no preço (P), a quantidade vendida (Q) diminuirá em duas unidades. Por exemplo, se o preço subir de $50 para $51, a quantidade vendida cairá de 100 para 98.
#
# Interpretação em Texto Simples:
# Se os preços dos widgets aumentam, as pessoas tendem a comprar menos. É uma situação comum em economia, onde um aumento no preço geralmente leva a uma redução na quantidade demandada. Este é um exemplo de como o coeficiente angular (-2 neste caso) em uma equação pode ajudar a entender a relação entre duas variáveis em um contexto econômico.

# %%
Image(url='https://cdn1.gnarususercontent.com.br/1/1310269/932b20ce-f5a3-4986-b435-5812b9f02b14.png')
# Out:
# <img src="https://cdn1.gnarususercontent.com.br/1/1310269/932b20ce-f5a3-4986-b435-5812b9f02b14.png"/>

# %% [markdown]
# Vale ressaltar que:
#
# â = coeficiente angular;
# n = número de elementos;
# Y = Moscow;
# X = datas.
